# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
import xarray as xr
import matplotlib.pyplot as plt

pd.options.plotting.backend = "plotly"

# %% [markdown]
# ## Load dataset
#
# ---

# %%
bats_bottle = xr.open_zarr("../../2_processed/bats_bottle.zarr")
bats_primary_production = xr.open_zarr("../../2_processed/bats_primary_production.zarr")
bats_zooplankton = xr.open_zarr("../../2_processed/bats_zooplankton.zarr")

# %%
bats_zooplankton
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:                                           (depth: 7, time: 1342,
#                                                        latitude: 1,
#                                                        longitude: 1,
#                                                        sieve_size: 5)
# Coordinates:
#   * depth                                             (depth) float64 56B 50....
#   * latitude                                          (latitude) float64 8B 31.6
#   * longitude                                         (longitude) float64 8B ...
#   * sieve_size                                        (sieve_size) float64 40B ...
#   * time                                              (time) datetime64[ns] 11kB ...
# Data variables:
#     dry_weight                                        (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     dry_weight_vol_water_ratio                        (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     dry_weight_vol_water_ratio_200m_depth             (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     total_dry_weight_volume_all_size_fractions_200m   (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     total_dry_weight_volume_all_size_fractions_ratio  (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     total_wet_weight_volume_all_size_fractions_200m   (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     total_wet_weight_volume_all_size_fractions_ratio  (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     volume_water                                      (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     wet_weight                                        (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     wet_weight_vol_water_ratio                        (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>
#     wet_weight_vol_water_ratio_200m_depth             (time, depth, latitude, longitude, sieve_size) float64 376kB dask.array<chunksize=(671, 7, 1, 1, 5), meta=np.ndarray>

# %%
bats_primary_production
# Out:
# <xarray.Dataset> Size: 260kB
# Dimensions:    (time: 445, depth: 8, latitude: 1, longitude: 1)
# Coordinates:
#   * depth      (depth) int64 64B 50 100 150 200 250 300 350 400
#   * latitude   (latitude) float64 8B 31.6
#   * longitude  (longitude) float64 8B -64.2
#   * time       (time) datetime64[ns] 4kB 1988-12-18 ... 2022-12-16T08:11:00
# Data variables:
#     dark       (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     lt1        (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     lt2        (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     lt3        (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     pp         (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     pres       (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     salt       (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     t0         (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>
#     temp       (time, depth, latitude, longitude) float64 28kB dask.array<chunksize=(445, 8, 1, 1), meta=np.ndarray>

# %%
bats_bottle
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:                        (time: 3754, depth: 8, latitude: 1,
#                                     longitude: 1)
# Coordinates:
#   * depth                          (depth) int64 64B 50 100 150 ... 300 350 400
#   * latitude                       (latitude) float64 8B 31.6
#   * longitude                      (longitude) float64 8B -64.2
#   * time                           (time) datetime64[ns] 30kB 1988-10-21T04:5...
# Data variables: (12/27)
#     CO2                            (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     CTD_salinity                   (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     POC                            (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     PON                            (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     POP                            (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     TN                             (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     ...                             ...
#     salinity                       (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     sigma_theta                    (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     silicate                       (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     synechococcus                  (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     temp                           (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>
#     total_dissolved_phosphorus     (time, depth, latitude, longitude) float64 240kB dask.array<chunksize=(3754, 8, 1, 1), meta=np.ndarray>

# %% [markdown]
# ## Manage index
#
# ---

# %%
times = pd.DataFrame(
    {
        "btl_time": bats_bottle.time.to_series(),
        "zpk_time": bats_zooplankton.time.to_series(),
        "pp_time": bats_primary_production.time.to_series(),
    }
)
fig = px.histogram(
    times,
    x=["btl_time", "zpk_time", "pp_time"],
    title="time distribution",
    opacity=0.5,
    log_y=True,
    nbins=30,
    barmode="overlay",
    marginal="box",
    labels={"value": "time (m)", "variable": "Datasets"},
)

fig.show()

# %%
depths = pd.DataFrame(
    {
        "ctd_depth": bats_bottle.depth.to_series(),
        "zpk_depth": bats_zooplankton.depth.to_series(),
        "pp_depth": bats_primary_production.depth.to_series(),
    }
)
px.box(
    depths.stack().reset_index().rename(columns={"level_1": "dataset"}),
    x="dataset",
    y="depth",
)

# %% [markdown]
# ## Migrant and resident

# %%
with xr.set_options(keep_attrs=True):
    night_condition = (bats_zooplankton.time.dt.hour > 18) | (
        bats_zooplankton.time.dt.hour < 6
    )

    bats_zooplankton = bats_zooplankton.assign_coords(is_night=night_condition)
    bats_zooplankton.is_night.attrs = {
        "flag_values": f"{[True, False]}",
        "flag_meanings": "night day",
        "standard_name": "is_night",
        "long_name": "Is night",
    }
    zpk_resident = (
        bats_zooplankton.swap_dims({"time": "is_night"})
        .sel(is_night=False)
        .swap_dims({"is_night": "time"})
        .drop_vars("is_night")
    )

    zpk_migrant = (
        bats_zooplankton.swap_dims({"time": "is_night"})
        .sel(is_night=True)
        .swap_dims({"is_night": "time"})
        .drop_vars("is_night")
    )
    zpk_resident = zpk_resident.resample(time="1D").mean().dropna("time", how="all")
    zpk_migrant = zpk_migrant.resample(time="1D").mean().dropna("time", how="all")
    zpk_migrant = zpk_migrant - zpk_resident
    zpk_migrant = xr.where(zpk_migrant > 0, zpk_migrant, 0).dropna("time", how="all")
    zpk_migrant = zpk_migrant[
        ["dry_weight_vol_water_ratio", "wet_weight_vol_water_ratio"]
    ].rename(
        {
            "dry_weight_vol_water_ratio": "dry_weight_migrant",
            "wet_weight_vol_water_ratio": "wet_weight_migrant",
        }
    )
    zpk_resident = zpk_resident[
        ["dry_weight_vol_water_ratio", "wet_weight_vol_water_ratio"]
    ].rename(
        {
            "dry_weight_vol_water_ratio": "dry_weight_resident",
            "wet_weight_vol_water_ratio": "wet_weight_resident",
        }
    )
    bats_zooplankton = xr.merge([zpk_migrant, zpk_resident])
    # reorder dims as : time -> lat -> lon -> depth -> sieve_size
    bats_zooplankton = bats_zooplankton.transpose(
        "sieve_size", "time", "latitude", "longitude", "depth"
    )
bats_zooplankton
# Out:
# <xarray.Dataset> Size: 383kB
# Dimensions:              (depth: 7, latitude: 1, longitude: 1, sieve_size: 5,
#                           time: 339)
# Coordinates:
#   * depth                (depth) float64 56B 50.0 100.0 150.0 ... 300.0 350.0
#   * latitude             (latitude) float64 8B 31.6
#   * longitude            (longitude) float64 8B -64.2
#   * sieve_size           (sieve_size) float64 40B 0.2 0.5 1.0 2.0 5.0
#   * time                 (time) datetime64[ns] 3kB 1995-05-11 ... 2022-12-13
# Data variables:
#     dry_weight_migrant   (sieve_size, time, latitude, longitude, depth) float64 95kB dask.array<chunksize=(5, 2, 1, 1, 7), meta=np.ndarray>
#     wet_weight_migrant   (sieve_size, time, latitude, longitude, depth) float64 95kB dask.array<chunksize=(5, 2, 1, 1, 7), meta=np.ndarray>
#     dry_weight_resident  (sieve_size, time, latitude, longitude, depth) float64 95kB dask.array<chunksize=(5, 1, 1, 1, 7), meta=np.ndarray>
#     wet_weight_resident  (sieve_size, time, latitude, longitude, depth) float64 95kB dask.array<chunksize=(5, 1, 1, 1, 7), meta=np.ndarray>

# %% [markdown]
# ## Gathering
#
# ---

# %% [markdown]
# # TODO : Select only the wanted variables in each dataset

# %%
# Temporary, need to select the temp to keep
bats_bottle = bats_bottle.drop_vars("temp")

# %%
final_dataset = xr.merge([bats_zooplankton, bats_primary_production, bats_bottle])
final_dataset.load()
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:                        (depth: 8, latitude: 1, longitude: 1,
#                                     sieve_size: 5, time: 4242)
# Coordinates:
#   * depth                          (depth) float64 64B 50.0 100.0 ... 400.0
#   * latitude                       (latitude) float64 8B 31.6
#   * longitude                      (longitude) float64 8B -64.2
#   * sieve_size                     (sieve_size) float64 40B 0.2 0.5 1.0 2.0 5.0
#   * time                           (time) datetime64[ns] 34kB 1988-10-21T04:5...
# Data variables: (12/39)
#     dry_weight_migrant             (sieve_size, time, latitude, longitude, depth) float64 1MB ...
#     wet_weight_migrant             (sieve_size, time, latitude, longitude, depth) float64 1MB ...
#     dry_weight_resident            (sieve_size, time, latitude, longitude, depth) float64 1MB ...
#     wet_weight_resident            (sieve_size, time, latitude, longitude, depth) float64 1MB ...
#     dark                           (time, depth, latitude, longitude) float64 271kB ...
#     lt1                            (time, depth, latitude, longitude) float64 271kB ...
#     ...                             ...
#     prochlorococcus                (time, depth, latitude, longitude) float64 271kB ...
#     salinity                       (time, depth, latitude, longitude) float64 271kB ...
#     sigma_theta                    (time, depth, latitude, longitude) float64 271kB ...
#     silicate                       (time, depth, latitude, longitude) float64 271kB ...
#     synechococcus                  (time, depth, latitude, longitude) float64 271kB ...
#     total_dissolved_phosphorus     (time, depth, latitude, longitude) float64 271kB ...

# %%
final_dataset.to_zarr("../../3_post_processed/bats_product.zarr", mode="w")
