# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblHOT_Macrozooplankton_v2022")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])

# %%
raw_data
# Out:
#                      time    lat  lon  depth  cruise  frac   tow  vol  svol  \
# 0     1994-02-17T11:08:00  22.75 -158    181  HOT052     0     8  726   NaN
# 1     1994-02-17T11:08:00  22.75 -158    181  HOT052     1     8  726   NaN
# 2     1994-02-17T11:08:00  22.75 -158    181  HOT052     2     8  726   NaN
# 3     1994-02-17T11:08:00  22.75 -158    181  HOT052     3     8  726   NaN
# 4     1994-02-17T11:08:00  22.75 -158    181  HOT052     4     8  726   NaN
# ...                   ...    ...  ...    ...     ...   ...   ...  ...   ...
# 9343  2022-09-02T22:13:00  22.75 -158    241  HOT339     1  1640  135   NaN
# 9344  2022-09-02T22:13:00  22.75 -158    241  HOT339     2  1640  135   NaN
# 9345  2022-09-02T22:13:00  22.75 -158    241  HOT339     3  1640  135   NaN
# 9346  2022-09-02T22:13:00  22.75 -158    241  HOT339     4  1640  135   NaN
# 9347  2022-09-02T22:13:00  22.75 -158    241  HOT339     5  1640  135   NaN
#
#           wwt     dwt    carb     nit    abnd
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblHOT_Macrozooplankton_v2022")

# %%
raw_meta
# Out:
#   Variable                     Table_Name        Long_Name   Unit  \
# 0     abnd  tblHOT_Macrozooplankton_v2022        Abundance   #/m2
# 1     carb  tblHOT_Macrozooplankton_v2022           Carbon  mg/m2
# 2   cruise  tblHOT_Macrozooplankton_v2022      Cruise Name    NaN
# 3      dwt  tblHOT_Macrozooplankton_v2022       Dry Weight   g/m2
# 4     frac  tblHOT_Macrozooplankton_v2022  Fraction Number    NaN
# 5      nit  tblHOT_Macrozooplankton_v2022         Nitrogen  mg/m2
# 6     svol  tblHOT_Macrozooplankton_v2022   Settled Volume  ml/m3
# 7      tow  tblHOT_Macrozooplankton_v2022       Tow Number    NaN
# 8      vol  tblHOT_Macrozooplankton_v2022           Volume     m3
# 9      wwt  tblHOT_Macrozooplankton_v2022       Wet Weight   g/m2
#
#           Make              Sensor Process_Level Study_Domain  \
# 0  Observation     Zooplankton Net   Reprocessed      Biology
# 1  Observation  Elemental Analyzer   Reprocessed      Biology
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/hot_zooplankton.csv")
raw_meta.to_csv("../../1_raw/hot_zooplankton_meta.csv")
