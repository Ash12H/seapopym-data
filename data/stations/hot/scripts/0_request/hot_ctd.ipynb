# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblHOT_CTD_v2022")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])

# %%
raw_data
# Out:
#                        time    lat  lon        depth  cruise  press    theta  \
# 0       1988-10-31T00:00:00  22.75 -158     0.000000  HOT001      0  26.2693
# 1       1988-10-31T00:00:00  22.75 -158     1.987433  HOT001      2  26.2691
# 2       1988-10-31T00:00:00  22.75 -158     3.974848  HOT001      4  26.2728
# 3       1988-10-31T00:00:00  22.75 -158     5.962242  HOT001      6  26.2710
# 4       1988-10-31T00:00:00  22.75 -158     7.949618  HOT001      8  26.2687
# ...                     ...    ...  ...          ...     ...    ...      ...
# 787340  2022-09-01T00:00:00  22.75 -158  4714.878626  HOT339   4798   1.0890
# 787341  2022-09-01T00:00:00  22.75 -158  4716.822879  HOT339   4800   1.0886
# 787342  2022-09-01T00:00:00  22.75 -158  4718.767116  HOT339   4802   1.0884
# 787343  2022-09-01T00:00:00  22.75 -158  4720.711335  HOT339   4804   1.0886
# 787344  2022-09-01T00:00:00  22.75 -158  4722.655538  HOT339   4806   1.0886
#
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblHOT_CTD_v2022")

# %%
raw_meta
# Out:
#   Variable        Table_Name              Long_Name            Unit  \
# 0   cruise  tblHOT_CTD_v2022            Cruise Name             NaN
# 1    fluor  tblHOT_CTD_v2022          Chloropigment           Âµg/l
# 2      nit  tblHOT_CTD_v2022          Nitrate (NO3)        Âµmol/kg
# 3      oxy  tblHOT_CTD_v2022                 Oxygen        Âµmol/kg
# 4    press  tblHOT_CTD_v2022               Pressure        decibars
# 5      sal  tblHOT_CTD_v2022               Salinity          PSS-78
# 6    sigma  tblHOT_CTD_v2022      Potential Density           kg/m3
# 7     temp  tblHOT_CTD_v2022            Temperature          ITS-90
# 8    theta  tblHOT_CTD_v2022  Potential Temperature          ITS-90
# 9    xmiss  tblHOT_CTD_v2022           Transmission  % transmission
#
#           Make         Sensor Process_Level     Study_Domain  \
# 0  Observation  Uncategorized   Reprocessed  Biogeochemistry
# 1  Observation            CTD   Reprocessed  Biogeochemistry
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/hot_ctd.csv")
raw_meta.to_csv("../../1_raw/hot_ctd_meta.csv")
