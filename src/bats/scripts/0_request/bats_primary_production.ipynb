# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblBATS_Primary_Production")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])

# %%
raw_data
# Out:
#                      time     lat     lon  depth          time_out  Lat_out  \
# 0     1988-12-18T00:00:00  31.669 -64.049    5.0  1988-12-18T00:00      NaN
# 1     1988-12-18T00:00:00  31.669 -64.049   25.0  1988-12-18T00:00      NaN
# 2     1988-12-18T00:00:00  31.669 -64.049   50.0  1988-12-18T00:00      NaN
# 3     1988-12-18T00:00:00  31.669 -64.049   75.0  1988-12-18T00:00      NaN
# 4     1988-12-18T00:00:00  31.669 -64.049  100.0  1988-12-18T00:00      NaN
# ...                   ...     ...     ...    ...               ...      ...
# 3517  2022-12-16T08:11:00  31.668 -64.167   61.5  2022-12-16T08:52   31.678
# 3518  2022-12-16T08:11:00  31.668 -64.167   79.7  2022-12-16T08:52   31.678
# 3519  2022-12-16T08:11:00  31.668 -64.167  101.8  2022-12-16T08:52   31.678
# 3520  2022-12-16T08:11:00  31.668 -64.167  122.5  2022-12-16T08:52   31.678
# 3521  2022-12-16T08:11:00  31.668 -64.167  137.4  2022-12-16T08:52   31.678
#
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblBATS_Primary_Production")

# %%
raw_meta
# Out:
#        Variable                  Table_Name  \
# 0     Cruise_ID  tblBATS_Primary_Production
# 1          dark  tblBATS_Primary_Production
# 2       Lat_out  tblBATS_Primary_Production
# 3      Long_out  tblBATS_Primary_Production
# 4           lt1  tblBATS_Primary_Production
# 5           lt2  tblBATS_Primary_Production
# 6           lt3  tblBATS_Primary_Production
# 7   niskin_flag  tblBATS_Primary_Production
# 8            pp  tblBATS_Primary_Production
# 9          pres  tblBATS_Primary_Production
# 10         salt  tblBATS_Primary_Production
# 11           t0  tblBATS_Primary_Production
# 12         temp  tblBATS_Primary_Production
# 13     time_out  tblBATS_Primary_Production
# 14        UNOLS  tblBATS_Primary_Production
#
#                                             Long_Name         Unit  \
# 0                                           Cruise ID          NaN
# 1                  14C Primary Production Dark Bottle  mgC/m^3/day
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/bats_primary_production.csv")
raw_meta.to_csv("../../1_raw/bats_primary_production_meta.csv")
