# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblHOT_PP_v2022")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])

# %%
raw_data
# Out:
#                      time    lat  lon  depth  cruise  stime   etime  itype  \
# 0     1988-10-31T00:00:00  22.75 -158     24  HOT001    NaN     NaN      0
# 1     1988-10-31T00:00:00  22.75 -158     42  HOT001    NaN     NaN      0
# 2     1988-10-31T00:00:00  22.75 -158     68  HOT001    NaN     NaN      0
# 3     1988-10-31T00:00:00  22.75 -158    114  HOT001    NaN     NaN      0
# 4     1988-12-02T00:00:00  22.75 -158      0  HOT002    NaN     NaN      0
# ...                   ...    ...  ...    ...     ...    ...     ...    ...
# 2584  2022-09-01T00:00:00  22.75 -158     75  HOT339  443.0  1948.0      2
# 2585  2022-09-01T00:00:00  22.75 -158    100  HOT339  443.0  1948.0      2
# 2586  2022-09-01T00:00:00  22.75 -158    125  HOT339  443.0  1948.0      2
# 2587  2022-09-01T00:00:00  22.75 -158    150  HOT339  443.0  1948.0      2
# 2588  2022-09-01T00:00:00  22.75 -158    175  HOT339  443.0  1948.0      2
#
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblHOT_PP_v2022")

# %%
raw_meta
# Out:
#    Variable       Table_Name                       Long_Name     Unit  \
# 0      bsal  tblHOT_PP_v2022                        Salinity   PSS-78
# 1       chl  tblHOT_PP_v2022                   Chlorophyll a    mg/m3
# 2    cruise  tblHOT_PP_v2022                     Cruise Name      NaN
# 3       d12  tblHOT_PP_v2022                         Dark 12  mg C/m3
# 4     ebact  tblHOT_PP_v2022                  picoEukaryotes     #/ml
# 5     etime  tblHOT_PP_v2022                        End Time     hhmm
# 6     hbact  tblHOT_PP_v2022          Heterotrophic Bacteria     #/ml
# 7     itype  tblHOT_PP_v2022  Sampling and Incubation Method      NaN
# 8       l12  tblHOT_PP_v2022                        Light 12  mg C/m3
# 9     pbact  tblHOT_PP_v2022                 Prochlorococcus     #/ml
# 10    phaeo  tblHOT_PP_v2022                    Pheopigments    mg/m3
# 11    sbact  tblHOT_PP_v2022                   Synechococcus     #/ml
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/hot_primary_production.csv")
raw_meta.to_csv("../../1_raw/hot_primary_production_meta.csv")
