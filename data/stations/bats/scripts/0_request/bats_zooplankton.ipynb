# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblBATS_Zooplankton_Biomass")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])

# %%
raw_data
# Out:
#                      time        lat        lon  depth  time_in  time_out  \
# 0     1995-05-10T00:00:00  31.662500 -64.169167  200.0     2320      2356
# 1     1995-05-10T00:00:00  31.662500 -64.169167  200.0     2320      2356
# 2     1995-05-10T00:00:00  31.662500 -64.169167  200.0     2320      2356
# 3     1995-05-10T00:00:00  31.662500 -64.169167  200.0     2320      2356
# 4     1995-05-10T00:00:00  31.662500 -64.169167  200.0     2320      2356
# ...                   ...        ...        ...    ...      ...       ...
# 6723  2022-12-13T00:00:00  31.697662 -64.152542  168.7     1249      1324
# 6724  2022-12-13T00:00:00  31.697662 -64.152542  168.7     1249      1324
# 6725  2022-12-13T00:00:00  31.697662 -64.152542  168.7     1249      1324
# 6726  2022-12-13T00:00:00  31.697662 -64.152542  168.7     1249      1324
# 6727  2022-12-13T00:00:00  31.697662 -64.152542  168.7     1249      1324
#
#       duration_minutes  volume_water  sieve_size  wet_weight  ...  \
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblBATS_Zooplankton_Biomass")

# %%
raw_meta
# Out:
#                                             Variable  \
# 0                                          Cruise_ID
# 1                                         dry_weight
# 2                         dry_weight_vol_water_ratio
# 3              dry_weight_vol_water_ratio_200m_depth
# 4                                   duration_minutes
# 5                                         sieve_size
# 6                                            time_in
# 7                                           time_out
# 8    total_dry_weight_volume_all_size_fractions_200m
# 9   total_dry_weight_volume_all_size_fractions_ratio
# 10   total_wet_weight_volume_all_size_fractions_200m
# 11  total_wet_weight_volume_all_size_fractions_ratio
# 12                                             UNOLS
# 13                                      volume_water
# 14                                        wet_weight
# 15                        wet_weight_vol_water_ratio
# 16             wet_weight_vol_water_ratio_200m_depth
#
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/bats_zooplankton.csv")
raw_meta.to_csv("../../1_raw/bats_zooplankton_meta.csv")
