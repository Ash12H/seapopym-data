# %%
import pycmap
import json

# %%
with open("../../../../.secrets") as f:
    secrets = json.load(f)
    cmap_token = secrets["simonscmap"]
cmap_api = pycmap.API(token=cmap_token)

# %% [markdown]
# ## Dataset
#
# ---

# %%
raw_data = cmap_api.get_dataset("tblBATS_Bottle")
# Out:
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:334: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(df['JSON_stats'][0])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:335: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   rows = int(df.loc[['count'], 'lat'])
# /Users/ash/Documents/Workspaces/PhD/seapopym-data/.venv/lib/python3.12/site-packages/pycmap/rest.py:140: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(StringIO(resp_text))

# %%
raw_data
# Out:
#                       time     lat     lon   depth    temp  CTD_salinity  \
# 0      1988-10-20T22:30:00  31.783 -64.116  2000.5   3.817           NaN
# 1      1988-10-20T22:30:00  31.783 -64.116  2200.3   3.577           NaN
# 2      1988-10-20T22:30:00  31.783 -64.116  2398.9   3.317           NaN
# 3      1988-10-20T22:30:00  31.783 -64.116  2600.0   3.127           NaN
# 4      1988-10-20T22:30:00  31.783 -64.116  2801.7   2.927           NaN
# ...                    ...     ...     ...     ...     ...           ...
# 67903  2022-12-16T16:07:00  31.700 -64.146   253.3  19.068        36.648
# 67904  2022-12-16T19:08:00  31.712 -64.140   810.5  10.145        35.316
# 67905  2022-12-16T19:08:00  31.712 -64.140   811.5  10.136        35.315
# 67906  2022-12-16T19:08:00  31.712 -64.140   811.7  10.135        35.315
# 67907  2022-12-16T19:08:00  31.712 -64.140   815.2  10.048        35.308
#
#        salinity  sigma_theta  oxygen  oxygen_fix_temp  ...  \
# ...

# %% [markdown]
# ## Metadata
#
# ---

# %%
raw_meta = cmap_api.get_dataset_metadata("tblBATS_Bottle")

# %%
raw_meta
# Out:
#                          Variable      Table_Name  \
# 0                      alkalinity  tblBATS_Bottle
# 1            bacteria_enumeration  tblBATS_Bottle
# 2                             CO2  tblBATS_Bottle
# 3                       cruise_ID  tblBATS_Bottle
# 4                    CTD_salinity  tblBATS_Bottle
# 5            low_level_phosphorus  tblBATS_Bottle
# 6                  nanoeukaryotes  tblBATS_Bottle
# 7                     niskin_flag  tblBATS_Bottle
# 8                 nitrate_nitrite  tblBATS_Bottle
# 9                         nitrite  tblBATS_Bottle
# 10                         oxygen  tblBATS_Bottle
# 11                 oxygen_anomaly  tblBATS_Bottle
# 12                oxygen_fix_temp  tblBATS_Bottle
# 13    particulate_biogenic_silica  tblBATS_Bottle
# 14  particulate_lithogenic_silica  tblBATS_Bottle
# 15                      phosphate  tblBATS_Bottle
# 16                 picoeukaryotes  tblBATS_Bottle
# 17                            POC  tblBATS_Bottle
# ...

# %% [markdown]
# ## Export
#
# ---

# %%
raw_data.to_csv("../../1_raw/bats_bottle.csv")
raw_meta.to_csv("../../1_raw/bats_bottle_meta.csv")
