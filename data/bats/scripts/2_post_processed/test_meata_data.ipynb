# %%
import pandas as pd
import xarray as xr

# %%
data = pd.read_csv("../../2_preprocessed/bats_zooplankton.csv")
data.head()
# Out:
#                   time   latitude  longitude    size  max depth  \
# 0  1994-04-06 15:58:00  31.564833 -63.874167   200.0        NaN
# 1  1994-04-06 15:58:00  31.564833 -63.874167   500.0        NaN
# 2  1994-04-06 15:58:00  31.564833 -63.874167  1000.0        NaN
# 3  1994-04-06 15:58:00  31.564833 -63.874167  2000.0        NaN
# 4  1994-04-06 15:58:00  31.564833 -63.874167  5000.0        NaN
#
#    duration minutes  volume of water (m^3)  wet weight (mg)  dry weight (mg)  \
# 0                28                135.501           2460.0            210.4
# 1                28                135.501           1220.0            120.2
# 2                28                135.501           2200.0            110.4
# 3                28                135.501            940.0             94.4
# 4                28                135.501            460.0             36.2
#
#    wet weight /volume of water ( mg/m^3)  \
# 0                                  18.15
# ...
